# %%
# We can use plotly, matplotlib and seaborn to do graphics in Python.
# In module_2 we started to do some plotting using seaborn.

# In the GitHub Terminal area, type "pip install statsmodels" <return>
# This installs something in GitHub that we refer to in this next line of code
import statsmodels as sm
import pandas as pd
import plotly.express as px
# the 'r' below means "read every character as the character it is"
# it is good practice to use the 'r' even when we don't need it
filepath = r'https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv'
df = pd.read_csv(filepath)
df.head()
# Out:
#              Name   Period  House price index All property types  \
# 0  United Kingdom  1980-01                                 10.11
# 1  United Kingdom  1980-02                                 10.11
# 2  United Kingdom  1980-03                                 10.11
# 3  United Kingdom  1980-04                                 10.51
# 4  United Kingdom  1980-05                                 10.51
#
#    Average price All property types  \
# 0                             19273
# 1                             19273
# 2                             19273
# 3                             20044
# 4                             20044
#
#    Percentage change (monthly) All property types  \
# 0                                            3.94
# 1                                            3.94
# 2                                            3.94
# 3                                            4.00
# 4                                            4.00
#
#    Percentage change (yearly) All property types
# 0                                          28.59
# 1                                          28.59
# 2                                          28.59
# 3                                          24.15
# 4                                          24.15

# %%
df['Period'] = pd.to_datetime(df['Period'], format="%Y-%m", errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Name                                            523 non-null    object
#  1   Period                                          523 non-null    datetime64[ns]
#  2   House price index All property types            523 non-null    float64
#  3   Average price All property types                523 non-null    int64
#  4   Percentage change (monthly) All property types  523 non-null    float64
#  5   Percentage change (yearly) All property types   523 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 24.6+ KB

# %%
# with the px.scatter command you define the data source, x axis field, y axis field
scatter_1 = px.scatter(df,
                       x='Period',
                       y='Average price All property types')
scatter_1.show()
# Out:
# <div>                            <div id="a2da6606-8c8f-4407-a290-910acd1b4923" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2da6606-8c8f-4407-a290-910acd1b4923")) {                    Plotly.newPlot(                        "a2da6606-8c8f-4407-a290-910acd1b4923",                        [{"hovertemplate":"Period=%{x}\u003cbr\u003eAverage price All property types=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1980-01-01T00:00:00","1980-02-01T00:00:00","1980-03-01T00:00:00","1980-04-01T00:00:00","1980-05-01T00:00:00","1980-06-01T00:00:00","1980-07-01T00:00:00","1980-08-01T00:00:00","1980-09-01T00:00:00","1980-10-01T00:00:00","1980-11-01T00:00:00","1980-12-01T00:00:00","1981-01-01T00:00:00","1981-02-01T00:00:00","1981-03-01T00:00:00","1981-04-01T00:00:00","1981-05-01T00:00:00","1981-06-01T00:00:00","1981-07-01T00:00:00","1981-08-01T00:00:00","1981-09-01T00:00:00","1981-10-01T00:00:00","1981-11-01T00:00:00","1981-12-01T00:00:00","1982-01-01T00:00:00","1982-02-01T00:00:00","1982-03-01T00:00:00","1982-04-01T00:00:00","1982-05-01T00:00:00","1982-06-01T00:00:00","1982-07-01T00:00:00","1982-08-01T00:00:00","1982-09-01T00:00:00","1982-10-01T00:00:00","1982-11-01T00:00:00","1982-12-01T00:00:00","1983-01-01T00:00:00","1983-02-01T00:00:00","1983-03-01T00:00:00","1983-04-01T00:00:00","1983-05-01T00:00:00","1983-06-01T00:00:00","1983-07
"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=9\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9","marker":{"color":"#FE00CE","pattern":{"shape":""}},"name":"9","offsetgroup":"9","orientation":"v","showlegend":true,"x":["N9","N1"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=2B\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2B","marker":{"color":"#0DF9FF","pattern":{"shape":""}},"name":"2B","offsetgroup":"2B","orientation":"v","showlegend":true,"x":["N3","N1","N7","N3","N3","N9"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=10\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10","marker":{"color":"#F6F926","pattern":{"shape":""}},"name":"10","offsetgroup":"10","orientation":"v","showlegend":true,"x":["N8","N6","N4"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=1A\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1A","marker":{"color":"#FF9616","pattern":{"shape":""}},"name":"1A","offsetgroup":"1A","orientation":"v","showlegend":true,"x":["N9","N0","N2","N1","N9"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=1B\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1B","marker":{"color":"#479B55","pattern":{"shape":""}},"name":"1B","offsetgroup":"1B","orientation":"v","showlegend":true,"x":["N1","N2","N0","N7","N3"],"xaxis":"x","yaxis":"y","type":"histo ...

# %%
hist_2c = px.histogram(df,
                    x='PrimaryNeedCode',
                    color='ReferralSource',
                    color_discrete_sequence=px.colors.qualitative.Light24,
                    barmode='group')
hist_2c.show()
# Out:
# <div>                            <div id="b846b382-b02a-438b-989b-9c029a0a7810" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b846b382-b02a-438b-989b-9c029a0a7810")) {                    Plotly.newPlot(                        "b846b382-b02a-438b-989b-9c029a0a7810",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=4\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#FD3216","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"v","showlegend":true,"x":["N6","N2"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=6\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"6","marker":{"color":"#00FE35","pattern":{"shape":""}},"name":"6","offsetgroup":"6","orientation":"v","showlegend":true,"x":["N8","N6","N4","N0","N6"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=3A\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3A","marker":{"color":"#6A76FC","pattern":{"shape":""}},"name":"3A","offsetgroup":"3A","orientation":"v","showlegend":true,"x":["N9","N2","N9","N9","N5","N6","N3","N1"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=2A\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2A","marker":{"color":"#FED4C4","pattern":{"shape":""}},"name":"2A","offsetgroup":"2A","orientation":"v","showlegend":true,"x":["N4","N3","N1","N8","N0","N2","N6","N9","N7","N6"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=9\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9","marker":{"color":"#FE00CE","pattern":{"shape":""}},"name":"9","offsetgroup":"9","orientation":"v","showlegend":true,"x":["N9","N1"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=2B\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2B","marker":{"color":"#0DF9FF","pattern":{"shape":""}},"name":"2B","offsetgroup":"2B","orientation":"v","showlegend":true,"x":["N3","N1","N7","N3","N3","N9"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=10\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10","marker":{"color":"#F6F926","pattern":{"shape":""}},"name":"10","offsetgroup":"10","orientation":"v","showlegend":true,"x":["N8","N6","N4"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=1A\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1A","marker":{"color":"#FF9616","pattern":{"shape":""}},"name":"1A","offsetgroup":"1A","orientation":"v","showlegend":true,"x":["N9","N0","N2","N1","N9"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=1B\u003cbr\u003ePrimaryNeedCode=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1B","marker":{"color":"#479B55","pattern":{"shape":""}},"name":"1B","offsetgroup":"1B","orientation":"v","showlegend":true,"x":["N1","N2","N0","N7","N3"],"xaxis":"x","yaxis":"y","type":"histo ...

# %%
import numpy as np
df['CPCTimeliness'] = df['DateOfInitialCPC'] - df['CINreferralDate']
# 'CPCTimeliness' needs to be reformatted, so that the field can be used in graphics work
df['CPCTimeliness'] = df['CPCTimeliness']/np.timedelta64(1, 'D')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        101 non-null    int64
#  1   LAchildID         101 non-null    object
#  2   CINdetailsID      101 non-null    int64
#  3   CINreferralDate   101 non-null    datetime64[ns]
#  4   ReferralSource    101 non-null    object
#  5   PrimaryNeedCode   101 non-null    object
#  6   CINclosureDate    63 non-null     datetime64[ns]
#  7   ReasonForClosure  63 non-null     object
#  8   DateOfInitialCPC  85 non-null     datetime64[ns]
#  9   ReferralNFA       101 non-null    bool
#  10  CPCTimeliness     85 non-null     float64
# dtypes: bool(1), datetime64[ns](3), float64(1), int64(2), object(4)
# memory usage: 8.1+ KB

# %%
time_hist = px.histogram(df,
                         x='CPCTimeliness',
                         nbins=20,
                         color='ReferralSource')
time_hist.show()
# Out:
# <div>                            <div id="4ad9847b-fa35-4d1c-8262-57947b4f7bdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ad9847b-fa35-4d1c-8262-57947b4f7bdf")) {                    Plotly.newPlot(                        "4ad9847b-fa35-4d1c-8262-57947b4f7bdf",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=4\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"4","nbinsx":20,"offsetgroup":"4","orientation":"v","showlegend":true,"x":[78.0,33.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=6\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"6","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"6","nbinsx":20,"offsetgroup":"6","orientation":"v","showlegend":true,"x":[49.0,12.0,66.0,34.0,null],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=3A\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3A","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"3A","nbinsx":20,"offsetgroup":"3A","orientation":"v","showlegend":true,"x":[14.0,19.0,66.0,84.0,39.0,36.0,69.0,81.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=2A\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2A","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2A","nbinsx":20,"offsetgroup":"2A","orientation":"v","showlegend":true,"x":[66.0,0.0,19.0,null,51.0,86.0,null,46.0,46.0,null],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=9\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"9","nbinsx":20,"offsetgroup":"9","orientation":"v","showlegend":true,"x":[83.0,1.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=2B\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2B","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"2B","nbinsx":20,"offsetgroup":"2B","orientation":"v","showlegend":true,"x":[3.0,68.0,50.0,4.0,27.0,10.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=10\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"10","nbinsx":20,"offsetgroup":"10","orientation":"v","showlegend":true,"x":[25.0,54.0,67.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=1A\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1A","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"1A","nbinsx":20,"offsetgroup":"1A","orientation":"v","showlegend":true,"x":[65.0,43.0,87.0,50.0,54.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ReferralSource=1B\u003cbr\u003eCPCTimeliness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1B","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"1B","nbinsx":20,"offsetgroup":"1B","orientation":"v", ...

# %%
df['ReferralYear'] = df['CINreferralDate'].dt.year

time_box = px.box(df,
                  x='ReferralYear',
                  y='CPCTimeliness')

time_box.show()
# Out:
# <div>                            <div id="8ac0ac75-5ef3-4548-9ddc-55ad61e2e835" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ac0ac75-5ef3-4548-9ddc-55ad61e2e835")) {                    Plotly.newPlot(                        "8ac0ac75-5ef3-4548-9ddc-55ad61e2e835",                        [{"alignmentgroup":"True","hovertemplate":"ReferralYear=%{x}\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2020,2013,2017,2020,2022,2016,2021,2022,2022,2018,2021,2018,2020,2012,2022,2014,2022,2013,2018,2020,2014,2022,2020,2012,2022,2017,2016,2006,2015,2010,2012,2008,2012,2019,2020,2020,2012,2018,2007,2018,2021,2013,2010,2020,2020,2009,2018,2020,2014,2014,2022,2015,2017,2005,2018,2017,2010,2020,2012,2015,2012,2012,2022,2009,2011,2016,2009,2021,2021,2013,2014,2013,2020,2019,2020,2013,2013,2007,2004,2020,2018,2018,2015,2021,2021,2008,2022,2016,2015,2019,2014,2022,2021,2014,2018,2020,2010,2019,2018,2018,2022],"x0":" ","xaxis":"x","y":[78.0,49.0,14.0,66.0,83.0,3.0,0.0,25.0,12.0,65.0,16.0,54.0,46.0,74.0,null,27.0,19.0,8.0,68.0,null,24.0,66.0,null,50.0,null,83.0,45.0,4.0,86.0,66.0,84.0,66.0,39.0,null,67.0,11.0,51.0,46.0,56.0,3.0,43.0,48.0,56.0,19.0,19.0,1.0,77.0,36.0,21.0,null,15.0,69.0,55.0,34.0,69.0,87.0,74.0,74.0,null,18.0,27.0,51.0,74.0,27.0,32.0,null,72.0,null,50.0,10.0,86.0,27.0,77.0,36.0,33.0,21.0,null,30.0,null,13.0,9.0,49.0,19.0,null,null,6.0,70.0,49.0,46.0,46.0,81.0,13.0,null,9.0,75.0,null,26.0,54.0,null,37.0,17.0],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks ...

# %%
time_box_2 = px.box(df,
                    y='CPCTimeliness',
                    color='ReferralSource')

time_box_2.show()
# Out:
# <div>                            <div id="69f726a4-e294-4365-bef9-f1ed5fe66a79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69f726a4-e294-4365-bef9-f1ed5fe66a79")) {                    Plotly.newPlot(                        "69f726a4-e294-4365-bef9-f1ed5fe66a79",                        [{"alignmentgroup":"True","hovertemplate":"ReferralSource=4\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#636efa"},"name":"4","notched":false,"offsetgroup":"4","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[78.0,33.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=6\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"6","marker":{"color":"#EF553B"},"name":"6","notched":false,"offsetgroup":"6","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[49.0,12.0,66.0,34.0,null],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=3A\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3A","marker":{"color":"#00cc96"},"name":"3A","notched":false,"offsetgroup":"3A","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[14.0,19.0,66.0,84.0,39.0,36.0,69.0,81.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=2A\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2A","marker":{"color":"#ab63fa"},"name":"2A","notched":false,"offsetgroup":"2A","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[66.0,0.0,19.0,null,51.0,86.0,null,46.0,46.0,null],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=9\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9","marker":{"color":"#FFA15A"},"name":"9","notched":false,"offsetgroup":"9","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[83.0,1.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=2B\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2B","marker":{"color":"#19d3f3"},"name":"2B","notched":false,"offsetgroup":"2B","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[3.0,68.0,50.0,4.0,27.0,10.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=10\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10","marker":{"color":"#FF6692"},"name":"10","notched":false,"offsetgroup":"10","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[25.0,54.0,67.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=1A\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1A","marker":{"color":"#B6E880"},"name":"1A","notched":false,"offsetgroup":"1A","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[65.0,43.0,87.0,50.0,54.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=1B\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1B","marker":{"color":"#FF97FF"},"name":"1B","notched":false,"offsetgroup":"1B","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[16.0,56.0,36.0,30.0,9.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"ReferralSource=8\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"8","marker":{"color":"#FECB52"},"name":"8","notched":false,"offsetgroup":"8","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[46.0,74.0,6.0],"y0":" ","yaxis":"y", ...

# %%
marginal = px.scatter(df,
                        x='CINreferralDate',
                        y='CPCTimeliness',
                        marginal_x='violin',
                        marginal_y='box',
                        #trendline='ols',
                        color='PrimaryNeedCode')
marginal.show()
# Out:
# <div>                            <div id="072b4408-a831-4362-b771-49b272c10091" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("072b4408-a831-4362-b771-49b272c10091")) {                    Plotly.newPlot(                        "072b4408-a831-4362-b771-49b272c10091",                        [{"hovertemplate":"PrimaryNeedCode=N6\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N6","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"N6","orientation":"v","showlegend":true,"x":["2020-07-13T00:00:00","2022-06-30T00:00:00","2018-11-10T00:00:00","2020-01-05T00:00:00","2022-06-25T00:00:00","2020-04-21T00:00:00","2016-10-10T00:00:00","2012-08-31T00:00:00","2010-02-19T00:00:00","2020-06-11T00:00:00","2022-03-09T00:00:00","2009-06-20T00:00:00","2021-05-22T00:00:00","2021-11-13T00:00:00","2020-08-18T00:00:00","2018-05-18T00:00:00"],"xaxis":"x","y":[78.0,12.0,54.0,46.0,null,null,45.0,51.0,56.0,36.0,74.0,72.0,null,null,null,null],"yaxis":"y","type":"scatter"},{"alignmentgroup":"True","hovertemplate":"PrimaryNeedCode=N6\u003cbr\u003eCINreferralDate=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N6","marker":{"color":"#636efa","symbol":"circle"},"name":"N6","offsetgroup":"N6","scalegroup":"x","showlegend":false,"x":["2020-07-13T00:00:00","2022-06-30T00:00:00","2018-11-10T00:00:00","2020-01-05T00:00:00","2022-06-25T00:00:00","2020-04-21T00:00:00","2016-10-10T00:00:00","2012-08-31T00:00:00","2010-02-19T00:00:00","2020-06-11T00:00:00","2022-03-09T00:00:00","2009-06-20T00:00:00","2021-05-22T00:00:00","2021-11-13T00:00:00","2020-08-18T00:00:00","2018-05-18T00:00:00"],"xaxis":"x3","yaxis":"y3","type":"violin"},{"alignmentgroup":"True","hovertemplate":"PrimaryNeedCode=N6\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N6","marker":{"color":"#636efa","symbol":"circle"},"name":"N6","notched":true,"offsetgroup":"N6","showlegend":false,"xaxis":"x2","y":[78.0,12.0,54.0,46.0,null,null,45.0,51.0,56.0,36.0,74.0,72.0,null,null,null,null],"yaxis":"y2","type":"box"},{"hovertemplate":"PrimaryNeedCode=N8\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N8","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"N8","orientation":"v","showlegend":true,"x":["2013-10-25T00:00:00","2022-01-30T00:00:00","2012-05-18T00:00:00","2013-08-29T00:00:00","2020-08-15T00:00:00","2020-10-27T00:00:00","2014-10-24T00:00:00","2022-01-05T00:00:00","2020-12-21T00:00:00","2012-04-29T00:00:00","2015-03-20T00:00:00","2021-01-24T00:00:00"],"xaxis":"x","y":[49.0,25.0,74.0,8.0,null,11.0,null,15.0,74.0,null,19.0,null],"yaxis":"y","type":"scatter"},{"alignmentgroup":"True","hovertemplate":"PrimaryNeedCode=N8\u003cbr\u003eCINreferralDate=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N8","marker":{"color":"#EF553B","symbol":"circle"},"name":"N8","offsetgroup":"N8","scalegroup":"x","showlegend":false,"x":["2013-10-25T00:00:00","2022-01-30T00:00:00","2012-05-18T00:00:00","2013-08-29T00:00:00","2020-08-15T00:00:00","2020-10-27T00:00:00","2014-10-24T00:00:00","2022-01-05T00:00:00","2020-12-21T00:00:00","2012-04-29T00:00:00","2015-03-20T00:00:00","2021-01-24T00:00:00"],"xaxis":"x3","yaxis":"y3","type":"violin"},{"alignmentgroup":"True","hovertemplate":"PrimaryNeedCode=N8\u003cbr\u003eCPCTimeliness=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N8","marker":{"color":"#EF553B","symbol":"circle"},"name":"N8","notched":true,"offsetgroup":"N8","showlegend":false,"xaxis":"x2","y":[49.0,25.0,74.0,8.0,null,11.0,null,15.0,74.0,null,19.0,null],"yaxis":"y2","type":"box"},{"hovertemplate":"PrimaryNeedCode=N9\u003cb ...

# %%
# in this example, Will demonstrates some axis labels that are not showing correctly
facet = px.histogram(df,
                    x='PrimaryNeedCode',
                    facet_row='ReferralYear')
facet.show()
# Out:
# <div>                            <div id="6afb026a-a308-4d1d-a1bd-41f0e6d42d0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
RC2","RC7","RC2","RC2","RC4","Still Open","RC4","Still Open","Still Open","RC5","RC1","RC8","RC1","RC6","Still Open","RC1","Still Open","Still Open","RC2","Still Open","RC5","RC6","Still Open","Still Open","Still Open","Still Open","RC3","Still Open","RC8","Still Open","RC8","RC4","Still Open","Still Open","Still Open","Still Open","RC5","Still Open","RC7","Still Open","RC2","RC3","RC3","RC1","RC2","Still Open","RC3","Still Open","Still Open","RC6","RC7","Still Open","RC4","Still Open","Still Open","RC6","Still Open","RC5","RC6","RC1","RC4","RC2","Still Open","RC7","RC7","RC5","RC6","RC3"]}],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"name":"","type":"parcats"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222 ...

# %%
time_df = df[df['CPCTimeliness'].notna()]

time_df = time_df[time_df['ReferralYear'] > 2010]

# %%
# the size code line was wrecking this.
# The px.scatter command could not work with the format of df['CPCTimeliness'] which was timedelta64[ns]
# when creating the field 'CPCTimeliness' we have to change the format to float64 e.g.
# df['CPCTimeliness'] = df['CPCTimeliness']/np.timedelta64(1, 'D')
scatter_3a = px.scatter(time_df,
                        x='CINreferralDate',
                        y='PrimaryNeedCode',                       
                        color='ReferralSource',
                        size='CPCTimeliness')
scatter_3a.show()
# Out:
# <div>                            <div id="1746734f-ddb3-481e-911b-304f715b9e13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1746734f-ddb3-481e-911b-304f715b9e13")) {                    Plotly.newPlot(                        "1746734f-ddb3-481e-911b-304f715b9e13",                        [{"hovertemplate":"ReferralSource=4\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#636efa","size":[78.0,33.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"4","orientation":"v","showlegend":true,"x":["2020-07-13T00:00:00","2020-05-08T00:00:00"],"xaxis":"x","y":["N6","N2"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=6\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"6","marker":{"color":"#EF553B","size":[49.0,12.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"6","orientation":"v","showlegend":true,"x":["2013-10-25T00:00:00","2022-06-30T00:00:00"],"xaxis":"x","y":["N8","N6"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=3A\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3A","marker":{"color":"#00cc96","size":[14.0,19.0,84.0,39.0,36.0,69.0,81.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"3A","orientation":"v","showlegend":true,"x":["2017-10-22T00:00:00","2022-04-21T00:00:00","2012-11-08T00:00:00","2012-10-26T00:00:00","2020-06-11T00:00:00","2018-01-23T00:00:00","2014-12-16T00:00:00"],"xaxis":"x","y":["N9","N2","N9","N5","N6","N3","N1"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=2A\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2A","marker":{"color":"#ab63fa","size":[66.0,0.0,19.0,51.0,86.0,46.0,46.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"2A","orientation":"v","showlegend":true,"x":["2020-01-14T00:00:00","2021-04-02T00:00:00","2020-11-21T00:00:00","2012-10-20T00:00:00","2014-11-01T00:00:00","2015-11-09T00:00:00","2019-12-30T00:00:00"],"xaxis":"x","y":["N4","N3","N1","N0","N2","N9","N7"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=9\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9","marker":{"color":"#FFA15A","size":[83.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"9","orientation":"v","showlegend":true,"x":["2022-02-07T00:00:00"],"xaxis":"x","y":["N9"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=2B\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2B","marker":{"color":"#19d3f3","size":[3.0,68.0,50.0,10.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"2B","orientation":"v","showlegend":true,"x":["2016-04-13T00:00:00","2018-06-15T00:00:00","2012-03-18T00:00:00","2013-12-14T00:00:00"],"xaxis":"x","y":["N3","N1","N7","N9"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=10\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10","marker":{"color":"#FF6692","size":[25.0,5 ...

# %%
time_df = df[df['CPCTimeliness'].notna()]

time_df = time_df[time_df['ReferralYear'] > 2010]

scatter_3b = px.scatter(time_df,
                       x='CINreferralDate',
                       y='PrimaryNeedCode',
                       size='CPCTimeliness',
                       color='ReferralSource',
                       range_x=[pd.to_datetime(2015, format='%Y'),pd.to_datetime(2020, format='%Y')],
                       )
scatter_3b.show()
# Out:
# <div>                            <div id="f6de70c9-8ad9-4ec1-8a17-a4ab59ec3867" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6de70c9-8ad9-4ec1-8a17-a4ab59ec3867")) {                    Plotly.newPlot(                        "f6de70c9-8ad9-4ec1-8a17-a4ab59ec3867",                        [{"hovertemplate":"ReferralSource=4\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#636efa","size":[78.0,33.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"4","orientation":"v","showlegend":true,"x":["2020-07-13T00:00:00","2020-05-08T00:00:00"],"xaxis":"x","y":["N6","N2"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=6\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"6","marker":{"color":"#EF553B","size":[49.0,12.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"6","orientation":"v","showlegend":true,"x":["2013-10-25T00:00:00","2022-06-30T00:00:00"],"xaxis":"x","y":["N8","N6"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=3A\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3A","marker":{"color":"#00cc96","size":[14.0,19.0,84.0,39.0,36.0,69.0,81.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"3A","orientation":"v","showlegend":true,"x":["2017-10-22T00:00:00","2022-04-21T00:00:00","2012-11-08T00:00:00","2012-10-26T00:00:00","2020-06-11T00:00:00","2018-01-23T00:00:00","2014-12-16T00:00:00"],"xaxis":"x","y":["N9","N2","N9","N5","N6","N3","N1"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=2A\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2A","marker":{"color":"#ab63fa","size":[66.0,0.0,19.0,51.0,86.0,46.0,46.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"2A","orientation":"v","showlegend":true,"x":["2020-01-14T00:00:00","2021-04-02T00:00:00","2020-11-21T00:00:00","2012-10-20T00:00:00","2014-11-01T00:00:00","2015-11-09T00:00:00","2019-12-30T00:00:00"],"xaxis":"x","y":["N4","N3","N1","N0","N2","N9","N7"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=9\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9","marker":{"color":"#FFA15A","size":[83.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"9","orientation":"v","showlegend":true,"x":["2022-02-07T00:00:00"],"xaxis":"x","y":["N9"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=2B\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2B","marker":{"color":"#19d3f3","size":[3.0,68.0,50.0,10.0],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"2B","orientation":"v","showlegend":true,"x":["2016-04-13T00:00:00","2018-06-15T00:00:00","2012-03-18T00:00:00","2013-12-14T00:00:00"],"xaxis":"x","y":["N3","N1","N7","N9"],"yaxis":"y","type":"scatter"},{"hovertemplate":"ReferralSource=10\u003cbr\u003eCINreferralDate=%{x}\u003cbr\u003ePrimaryNeedCode=%{y}\u003cbr\u003eCPCTimeliness=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10","marker":{"color":"#FF6692","size":[25.0,5 ...

# %%
df = px.data.gapminder()

fig = px.scatter(df,
                 x='gdpPercap',
                 y='lifeExp',
                 log_x=True,
                 hover_name='country',
                 color='continent',
                 size='pop',
                 facet_col='continent',
                 facet_col_wrap=2,
                 size_max=45,
                 animation_frame='year',
                 animation_group='country',
                 range_x=[100,120000],
                 range_y=[25,100])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = px.data.gapminder()
#       3 fig = px.scatter(df,
#       4                  x='gdpPercap',
#       5                  y='lifeExp',
#    (...)
#      15                  range_x=[100,120000],
#      16                  range_y=[25,100])
#      18 fig.show()
#
# NameError: name 'px' is not defined
